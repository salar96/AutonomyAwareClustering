# %%
# %env CUDA_LAUNCH_BLOCKING=1
import numpy as np
import torch
from ADEN import ADEN
from torchinfo import summary
from TestCaseGenerator import data_RLClustering
from ADENTrain import TrainAnneal
import utils
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
utils.set_seed(0)
# Out:
# env: CUDA_LAUNCH_BLOCKING=1
# Using device: cuda
# [Seed fixed to 0]
# Using device: cuda
# [Seed fixed to 0]

# %% [markdown]
# # Loading Data

# %%
# FOR SYNTHETIC DATA
X, M, T_P, N, d = data_RLClustering(4)
X = torch.tensor(X).float().to(device)
Y = torch.mean(X, dim=0, keepdim=True).to(device) + 0.01 * torch.randn(M, d).to(device)
scenario_name = f"IDX4_M{M}"

# %%
# # FOR DECENTRALIZED SENSING DATA
# import scipy
# address = f"UTD19_London.mat"
# # read as numpy array
# data = scipy.io.loadmat(address)
# locs = data['Xz']
# # normalize locs to be in [0,1]x[0,1]
# locs = (locs - np.min(locs, axis=0)) / (np.max(locs, axis=0) - np.min(locs, axis=0))
# X = torch.tensor(locs).float().to(device)
# N, d = X.shape
# M = 50
# Y = torch.mean(X, dim=0, keepdim=True).to(device) + 0.01 * torch.randn(M, d).to(device)
# T_P = 0.0
# scenario_name = f"UDT_M{M}"

# %% [markdown]
# # Creating Environment

# %%
kappa = 0.2
gamma = 0.0
zeta = 1.0
T = 0.01
parametrized = True
from Env import ClusteringEnvTorch

env = ClusteringEnvTorch(
    n_data=N,
    n_clusters=M,
    n_features=d,
    parametrized=parametrized,
    kappa=kappa,
    gamma=gamma,
    zeta=zeta,
    T=T,
    T_p=torch.tensor(T_P),
    device=device,
)
scenario_name += f"kappa{kappa}gam{gamma}zet{zeta}T{T}"

# %% [markdown]
# # Loading ADEN Model

# %%
INPUT_DIM = d  # dimensionality of the input space
D_MODEL = 64  # dimensionality of the model
N_LAYERS = 4  # number of layers
N_HEADS = 8  # number of attention heads
D_FF = 128  # dimensionality of the feedforward network
DROPOUT = 0.01  # dropout rate

model = ADEN(
    input_dim=INPUT_DIM,
    d_model=D_MODEL,
    n_layers=N_LAYERS,
    n_heads=N_HEADS,
    d_ff=D_FF,
    dropout=DROPOUT,
    device=device
)

print(summary(model))
scenario_name += f"D{D_MODEL}_L{N_LAYERS}_H{N_HEADS}_FF{D_FF}_DO{DROPOUT}_"
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# ADEN                                               --
# ├─Linear: 1-1                                      192
# ├─Linear: 1-2                                      192
# ├─ModuleList: 1-3                                  --
# │    └─AdaptiveDistanceBlock: 2-1                  --
# │    │    └─MultiHeadDistanceAttention: 3-1        16,448
# │    │    └─LayerNorm: 3-2                         128
# │    │    └─LayerNorm: 3-3                         128
# │    │    └─Sequential: 3-4                        16,576
# │    │    └─Dropout: 3-5                           --
# │    └─AdaptiveDistanceBlock: 2-2                  --
# │    │    └─MultiHeadDistanceAttention: 3-6        16,448
# │    │    └─LayerNorm: 3-7                         128
# │    │    └─LayerNorm: 3-8                         128
# │    │    └─Sequential: 3-9                        16,576
# │    │    └─Dropout: 3-10                          --
# │    └─AdaptiveDistanceBlock: 2-3                  --
# │    │    └─MultiHeadDistanceAttention: 3-11       16,448
# │    │    └─LayerNorm: 3-12                        128
# │    │    └─LayerNorm: 3-13                        128
# │    │    └─Sequential: 3-14                       16,576
# │    │    └─Dropout: 3-15                          --
# │    └─AdaptiveDistanceBlock: 2-4                  --
# │    │    └─MultiHeadDistanceAttention: 3-16       16,448
# │    │    └─LayerNorm: 3-17                        128
# │    │    └─LayerNorm: 3-18                        128
# │    │    └─Sequential: 3-19                       16,576
# │    │    └─Dropout: 3-20                          --
# ├─LayerNorm: 1-4                                   128
# ├─Sequential: 1-5                                  --
# │    └─Linear: 2-5                                 8,256
# │    └─GELU: 2-6                                   --
# │    └─Dropout: 2-7                                --
# │    └─Linear: 2-8                                 2,080
# │    └─GELU: 2-9                                   --
# │    └─Dropout: 2-10                               --
# │    └─Linear: 2-11                                33
# ===========================================================================
# Total params: 144,001
# Trainable params: 144,001
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# # Main Annealing Loop

# %%
# add tensorboard writer
from torch.utils.tensorboard import SummaryWriter

# writing all hyperparameters in one place
EPOCHS_DBAR = 2000
BATCH_SIZE_DBAR = 32
NUM_SAMPLES_IN_BATCH_DBAR = 128
LR_DBAR = 1e-4
WEIGHT_DECAY_DBAR = 1e-5
TOL_TRAIN_DBAR = 1e-6
PROBS_DBAR = torch.tensor(T_P)

EPOCHS_TRAIN_Y = 100 
BATCH_SIZE_TRAIN_Y = None
LR_TRAIN_Y = 1e-4 
WEIGHT_DECAY_TRAIN_Y = 1e-5
TOL_TRAIN_Y = 1e-4

BETA_INIT = 10.0
BETA_F = 100.0
BETA_GROWTH_RATE = 1.1 
PERTURBATION_STD = 0.01 

scenario_name += f"EpD{EPOCHS_DBAR}BSD{BATCH_SIZE_DBAR}NSD{NUM_SAMPLES_IN_BATCH_DBAR}LRD{LR_DBAR}"
scenario_name += f"EpY{EPOCHS_TRAIN_Y}LRY{LR_TRAIN_Y}"
scenario_name += f"_{BETA_INIT}to{BETA_F}rate{BETA_GROWTH_RATE}_Pert{PERTURBATION_STD}"

writer = SummaryWriter(log_dir=f"runs/{scenario_name}")

Y_opt, pi, history_y_all, history_pi_all , Betas = TrainAnneal(
    model,
    X,
    Y,
    env,
    device,
    # TrainDbar hyperparameters
    epochs_dbar=EPOCHS_DBAR,
    batch_size_dbar=BATCH_SIZE_DBAR,
    num_samples_in_batch_dbar=NUM_SAMPLES_IN_BATCH_DBAR,
    lr_dbar=LR_DBAR,
    weight_decay_dbar=WEIGHT_DECAY_DBAR,
    tol_train_dbar=TOL_TRAIN_DBAR,
    # trainY hyperparameters
    epochs_train_y=EPOCHS_TRAIN_Y,
    batch_size_train_y=BATCH_SIZE_TRAIN_Y,
    lr_train_y=LR_TRAIN_Y,
    weight_decay_train_y=WEIGHT_DECAY_TRAIN_Y,
    tol_train_y=TOL_TRAIN_Y,
    # annealing schedule
    beta_init=BETA_INIT,
    beta_final=BETA_F,
    beta_growth_rate=BETA_GROWTH_RATE,
    perturbation_std=PERTURBATION_STD,
    writer=writer,
)
writer.close()
# Out:
# === Annealing step: Beta = 1.000e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 1.015e+02
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 1.015e+02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.352e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.352e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 3.826e-01
# [trainY] Epoch 0, F: 4.769e-02
# [trainY] Converged at epoch 1, F: 4.769e-02
#
# === Annealing step: Beta = 1.100e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 7.027e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 3.826e-01
# [trainY] Epoch 0, F: 4.769e-02
# [trainY] Converged at epoch 1, F: 4.769e-02
#
# === Annealing step: Beta = 1.100e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 7.027e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 2.083e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 2.083e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.565e-01
# [trainY] Epoch 0, F: 5.875e-02
# [trainY] Converged at epoch 1, F: 5.875e-02
#
# === Annealing step: Beta = 1.210e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.810e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.565e-01
# [trainY] Epoch 0, F: 5.875e-02
# [trainY] Converged at epoch 1, F: 5.875e-02
#
# === Annealing step: Beta = 1.210e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.810e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.223e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.223e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.001e-01
# [trainY] Epoch 0, F: 6.931e-02
# [trainY] Converged at epoch 1, F: 6.931e-02
#
# === Annealing step: Beta = 1.331e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.206e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.001e-01
# [trainY] Epoch 0, F: 6.931e-02
# [trainY] Converged at epoch 1, F: 6.931e-02
#
# === Annealing step: Beta = 1.331e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.206e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.905e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.905e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.090e-02
# [trainY] Epoch 0, F: 7.920e-02
# [trainY] Converged at epoch 1, F: 7.920e-02
#
# === Annealing step: Beta = 1.464e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.161e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.090e-02
# [trainY] Epoch 0, F: 7.920e-02
# [trainY] Converged at epoch 1, F: 7.920e-02
#
# === Annealing step: Beta = 1.464e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.161e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.051e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.051e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 7.858e-02
# [trainY] Epoch 0, F: 8.902e-02
# [trainY] Converged at epoch 1, F: 8.902e-02
#
# === Annealing step: Beta = 1.611e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.468e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 7.858e-02
# [trainY] Epoch 0, F: 8.902e-02
# [trainY] Converged at epoch 1, F: 8.902e-02
#
# === Annealing step: Beta = 1.611e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.468e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.678e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.678e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 7.703e-02
# [trainY] Epoch 0, F: 9.682e-02
# [trainY] Converged at epoch 1, F: 9.682e-02
#
# === Annealing step: Beta = 1.772e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.909e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 7.703e-02
# [trainY] Epoch 0, F: 9.682e-02
# [trainY] Converged at epoch 1, F: 9.682e-02
#
# === Annealing step: Beta = 1.772e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.909e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.613e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.613e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.620e-02
# [trainY] Epoch 0, F: 1.043e-01
# [trainY] Converged at epoch 1, F: 1.043e-01
#
# === Annealing step: Beta = 1.949e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.993e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.620e-02
# [trainY] Epoch 0, F: 1.043e-01
# [trainY] Converged at epoch 1, F: 1.043e-01
#
# === Annealing step: Beta = 1.949e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.993e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.580e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.580e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.281e-02
# [trainY] Epoch 0, F: 1.114e-01
# [trainY] Converged at epoch 1, F: 1.114e-01
#
# === Annealing step: Beta = 2.144e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.178e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.281e-02
# [trainY] Epoch 0, F: 1.114e-01
# [trainY] Converged at epoch 1, F: 1.114e-01
#
# === Annealing step: Beta = 2.144e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.178e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.043e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.043e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.875e-02
# [trainY] Epoch 0, F: 1.177e-01
# [trainY] Converged at epoch 1, F: 1.177e-01
#
# === Annealing step: Beta = 2.358e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.856e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.875e-02
# [trainY] Epoch 0, F: 1.177e-01
# [trainY] Converged at epoch 1, F: 1.177e-01
#
# === Annealing step: Beta = 2.358e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.856e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.243e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.243e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.182e-02
# [trainY] Epoch 0, F: 1.234e-01
# [trainY] Converged at epoch 1, F: 1.234e-01
#
# === Annealing step: Beta = 2.594e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.962e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.182e-02
# [trainY] Epoch 0, F: 1.234e-01
# [trainY] Converged at epoch 1, F: 1.234e-01
#
# === Annealing step: Beta = 2.594e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.962e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.413e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.413e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.589e-02
# [trainY] Epoch 0, F: 1.287e-01
# [trainY] Converged at epoch 1, F: 1.287e-01
#
# === Annealing step: Beta = 2.853e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.058e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.589e-02
# [trainY] Epoch 0, F: 1.287e-01
# [trainY] Converged at epoch 1, F: 1.287e-01
#
# === Annealing step: Beta = 2.853e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.058e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.729e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.729e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.535e-02
# [trainY] Epoch 0, F: 1.334e-01
# [trainY] Converged at epoch 1, F: 1.334e-01
#
# === Annealing step: Beta = 3.138e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.035e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 6.535e-02
# [trainY] Epoch 0, F: 1.334e-01
# [trainY] Converged at epoch 1, F: 1.334e-01
#
# === Annealing step: Beta = 3.138e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.035e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.875e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.875e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.763e-02
# [trainY] Epoch 0, F: 1.375e-01
# [trainY] Converged at epoch 1, F: 1.375e-01
#
# === Annealing step: Beta = 3.452e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.071e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.763e-02
# [trainY] Epoch 0, F: 1.375e-01
# [trainY] Converged at epoch 1, F: 1.375e-01
#
# === Annealing step: Beta = 3.452e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.071e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.285e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.285e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.835e-02
# [trainY] Epoch 0, F: 1.415e-01
# [trainY] Converged at epoch 1, F: 1.414e-01
#
# === Annealing step: Beta = 3.797e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.849e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.835e-02
# [trainY] Epoch 0, F: 1.415e-01
# [trainY] Converged at epoch 1, F: 1.414e-01
#
# === Annealing step: Beta = 3.797e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.849e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.012e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.012e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.565e-02
# [trainY] Epoch 0, F: 1.448e-01
# [trainY] Converged at epoch 1, F: 1.448e-01
#
# === Annealing step: Beta = 4.177e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.790e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.565e-02
# [trainY] Epoch 0, F: 1.448e-01
# [trainY] Converged at epoch 1, F: 1.448e-01
#
# === Annealing step: Beta = 4.177e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.790e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.920e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.920e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.440e-02
# [trainY] Epoch 0, F: 1.482e-01
# [trainY] Converged at epoch 1, F: 1.482e-01
#
# === Annealing step: Beta = 4.595e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.010e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.440e-02
# [trainY] Epoch 0, F: 1.482e-01
# [trainY] Converged at epoch 1, F: 1.482e-01
#
# === Annealing step: Beta = 4.595e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.010e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.524e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.524e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.941e-02
# [trainY] Epoch 0, F: 1.514e-01
# [trainY] Converged at epoch 1, F: 1.514e-01
#
# === Annealing step: Beta = 5.054e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.302e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.941e-02
# [trainY] Epoch 0, F: 1.514e-01
# [trainY] Converged at epoch 1, F: 1.514e-01
#
# === Annealing step: Beta = 5.054e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.302e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.427e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.427e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.933e-02
# [trainY] Epoch 0, F: 1.540e-01
# [trainY] Converged at epoch 1, F: 1.540e-01
#
# === Annealing step: Beta = 5.560e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.176e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.933e-02
# [trainY] Epoch 0, F: 1.540e-01
# [trainY] Converged at epoch 1, F: 1.540e-01
#
# === Annealing step: Beta = 5.560e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.176e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.382e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.382e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.062e-02
# [trainY] Epoch 0, F: 1.557e-01
# [trainY] Converged at epoch 1, F: 1.557e-01
#
# === Annealing step: Beta = 6.116e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.662e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.062e-02
# [trainY] Epoch 0, F: 1.557e-01
# [trainY] Converged at epoch 1, F: 1.557e-01
#
# === Annealing step: Beta = 6.116e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.662e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.186e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.186e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.874e-02
# [trainY] Epoch 0, F: 1.581e-01
# [trainY] Converged at epoch 1, F: 1.581e-01
#
# === Annealing step: Beta = 6.727e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.794e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.874e-02
# [trainY] Epoch 0, F: 1.581e-01
# [trainY] Converged at epoch 1, F: 1.581e-01
#
# === Annealing step: Beta = 6.727e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.794e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.743e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.743e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.476e-02
# [trainY] Epoch 0, F: 1.597e-01
# [trainY] Converged at epoch 1, F: 1.597e-01
#
# === Annealing step: Beta = 7.400e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.532e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.476e-02
# [trainY] Epoch 0, F: 1.597e-01
# [trainY] Converged at epoch 1, F: 1.597e-01
#
# === Annealing step: Beta = 7.400e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.532e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.118e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 6.118e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.264e-02
# [trainY] Epoch 0, F: 1.620e-01
# [trainY] Converged at epoch 1, F: 1.620e-01
#
# === Annealing step: Beta = 8.140e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.964e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.264e-02
# [trainY] Epoch 0, F: 1.620e-01
# [trainY] Converged at epoch 1, F: 1.620e-01
#
# === Annealing step: Beta = 8.140e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.964e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.083e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.083e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.941e-02
# [trainY] Epoch 0, F: 1.630e-01
# [trainY] Converged at epoch 1, F: 1.630e-01
#
# === Annealing step: Beta = 8.954e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.779e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 4.941e-02
# [trainY] Epoch 0, F: 1.630e-01
# [trainY] Converged at epoch 1, F: 1.630e-01
#
# === Annealing step: Beta = 8.954e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.779e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.708e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 5.708e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.034e-02
# [trainY] Epoch 0, F: 1.645e-01
# [trainY] Converged at epoch 1, F: 1.645e-01
#
# === Annealing step: Beta = 9.850e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.033e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.034e-02
# [trainY] Epoch 0, F: 1.645e-01
# [trainY] Converged at epoch 1, F: 1.645e-01
#
# === Annealing step: Beta = 9.850e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.033e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.399e-02
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.399e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.325e-02
# [trainY] Epoch 0, F: 1.659e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 5.325e-02
# [trainY] Epoch 0, F: 1.659e-01

# %%
from Plotter import PlotClustering
from Env import ClusteringEnvNumpy, ClusteringEnvTorch
try:
    X_np = X.detach().cpu().numpy()
    y_np = Y_opt.detach().cpu().numpy()
except:
    X_np = X
    y_np = Y_opt
print(scenario_name)
PlotClustering(
    X_np,
    y_np,
    pi,
    figsize=(12, 6),
    cmap="gist_rainbow",
    point_size=10,
    centroid_size=200,
    alpha=0.9,
    data_edge_color='white',
    cluster_edge_color='black',
    save_path=f"Results/{scenario_name}.png",
)
from ClusteringGroundTruth import distortion
# kappa = float(scenario_name.split("_kappa")[1].split("_")[0])
# gamma = float(scenario_name.split("_gamma")[1].split("_")[0])
# zeta = float(scenario_name.split("_zeta")[1].split("_")[0])
# T = float(scenario_name.split("_T")[1].split("_")[0])
# N = X_np.shape[0]
# d = X_np.shape[1]
# M = y_np.shape[0]
env = ClusteringEnvNumpy(
    n_data=N,
    n_clusters=M,
    n_features=d,
    parametrized=True,
    kappa=kappa,
    gamma=gamma,
    zeta=zeta,
    T=T,
    T_p=None,
)
rho = np.ones(N) / N  # Uniform weights
print("Distortion:", distortion(X_np, y_np, rho, pi, env))
# Out:
# IDX4_M4kappa0.2gam0.0zet1.0T0.01D64_L4_H8_FF128_DO0.01_EpD2000BSD32NSD128LRD0.0001EpY100LRY0.0001_10.0to100.0rate1.1_Pert0.01
# Distortion: 0.17226411877207895

# %% [markdown]
# # Save the Results

# %%
# import pickle



# save_dict = {
#     "N": N,
#     "M": M,
#     "d": d,
#     # Hyperparameters
#     "EPOCHS_DBAR": EPOCHS_DBAR,
#     "BATCH_SIZE_DBAR": BATCH_SIZE_DBAR,
#     "NUM_SAMPLES_IN_BATCH_DBAR": NUM_SAMPLES_IN_BATCH_DBAR,
#     "LR_DBAR": LR_DBAR,
#     "WEIGHT_DECAY_DBAR": WEIGHT_DECAY_DBAR,
#     "TOL_TRAIN_DBAR": TOL_TRAIN_DBAR,
#     "PROBS_DBAR": PROBS_DBAR,
#     "EPOCHS_TRAIN_Y": EPOCHS_TRAIN_Y,
#     "BATCH_SIZE_TRAIN_Y": BATCH_SIZE_TRAIN_Y,
#     "LR_TRAIN_Y": LR_TRAIN_Y,
#     "WEIGHT_DECAY_TRAIN_Y": WEIGHT_DECAY_TRAIN_Y,
#     "TOL_TRAIN_Y": TOL_TRAIN_Y,
#     "BETA_INIT": BETA_INIT,
#     "BETA_F": BETA_F,
#     "BETA_GROWTH_RATE": BETA_GROWTH_RATE,
#     "PERTURBATION_STD": PERTURBATION_STD,
#     # Results
#     "X": X,
#     "Y_opt": Y_opt,
#     "history_y_all": history_y_all,
#     "history_pi_all": history_pi_all,
#     # Model architecture
#     "INPUT_DIM": INPUT_DIM,
#     "D_MODEL": D_MODEL,
#     "N_LAYERS": N_LAYERS,
#     "N_HEADS": N_HEADS,
#     "D_FF": D_FF,
#     "DROPOUT": DROPOUT
# }

# with open(f"Results/{scenario_name}.pkl", "wb") as f:
#     pickle.dump(save_dict, f)

# %% [markdown]
# # Load the Results

# %%
import pickle
# Now craete a load function to load the results
scenario_name = "Benchmark_UDT_kappa0.4_gamma0.0_zeta1.0_T0.01_20250923_000118"
def load_results(scenario_name):
    with open(f"BenchmarkUDT/{scenario_name}.pkl", "rb") as f:
        data = pickle.load(f)
    return data
results = load_results(scenario_name)
X = results["X"]
Y_opt = results["Y_opt"]
# history_y_all = results["history_y_all"]
# history_pi_all = results["history_pi_all"]
# pi = history_pi_all[-1]
pi = results["pi_opt"]

# %%
from animator import animate_Clusters
# history_pi_all[0] = history_pi_all[1]
animate_Clusters(
    X.detach().cpu().numpy(),
    history_y_all,
    history_pi_all,
    Betas,
    interval=250,
    save_path=f"Results/{scenario_name}.gif",
)
