# %%
# %env CUDA_LAUNCH_BLOCKING=1
import numpy as np
import torch
from ADEN import ADEN
from torchinfo import summary
from TestCaseGenerator import data_RLClustering
from ADENTrain import TrainAnneal
import utils
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
utils.set_seed(0)
# Out:
# env: CUDA_LAUNCH_BLOCKING=1
# Using device: cuda
# [Seed fixed to 0]

# %% [markdown]
# # Loading Data

# %%
# # FOR SYNTHETIC DATA
# X, M, T_P, N, d = data_RLClustering(4)
# X = torch.tensor(X).float().to(device)
# Y = torch.mean(X, dim=0, keepdim=True).to(device) + 0.01 * torch.randn(M, d).to(device)
# scenario_name = f"IDX4_M{M}"

# %%
# FOR DECENTRALIZED SENSING DATA
import scipy
address = f"UTD19_London.mat"
# read as numpy array
data = scipy.io.loadmat(address)
locs = data['Xz']
# normalize locs to be in [0,1]x[0,1]
locs = (locs - np.min(locs, axis=0)) / (np.max(locs, axis=0) - np.min(locs, axis=0))
X = torch.tensor(locs).float().to(device)
N, d = X.shape
M = 50
Y = torch.mean(X, dim=0, keepdim=True).to(device) + 0.01 * torch.randn(M, d).to(device)
T_P = 0.0
scenario_name = f"UDT_M{M}"

# %% [markdown]
# # Creating Environment

# %%
kappa = 0.4
gamma = 0.0
zeta = 1.0
T = 0.01
parametrized = True
from Env import ClusteringEnvTorch

env = ClusteringEnvTorch(
    n_data=N,
    n_clusters=M,
    n_features=d,
    parametrized=parametrized,
    kappa=kappa,
    gamma=gamma,
    zeta=zeta,
    T=T,
    T_p=torch.tensor(T_P),
    device=device,
)
scenario_name += f"kappa{kappa}gam{gamma}zet{zeta}T{T}"

# %% [markdown]
# # Loading ADEN Model

# %%
INPUT_DIM = d  # dimensionality of the input space
D_MODEL = 64  # dimensionality of the model
N_LAYERS = 4  # number of layers
N_HEADS = 8  # number of attention heads
D_FF = 128  # dimensionality of the feedforward network
DROPOUT = 0.01  # dropout rate

model = ADEN(
    input_dim=INPUT_DIM,
    d_model=D_MODEL,
    n_layers=N_LAYERS,
    n_heads=N_HEADS,
    d_ff=D_FF,
    dropout=DROPOUT,
    device=device
)

print(summary(model))
scenario_name += f"D{D_MODEL}_L{N_LAYERS}_H{N_HEADS}_FF{D_FF}_DO{DROPOUT}_"
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# ADEN                                               --
# ├─Linear: 1-1                                      192
# ├─Linear: 1-2                                      192
# ├─ModuleList: 1-3                                  --
# │    └─AdaptiveDistanceBlock: 2-1                  --
# │    │    └─MultiHeadDistanceAttention: 3-1        16,448
# │    │    └─LayerNorm: 3-2                         128
# │    │    └─LayerNorm: 3-3                         128
# │    │    └─Sequential: 3-4                        16,576
# │    │    └─Dropout: 3-5                           --
# │    └─AdaptiveDistanceBlock: 2-2                  --
# │    │    └─MultiHeadDistanceAttention: 3-6        16,448
# │    │    └─LayerNorm: 3-7                         128
# │    │    └─LayerNorm: 3-8                         128
# │    │    └─Sequential: 3-9                        16,576
# │    │    └─Dropout: 3-10                          --
# │    └─AdaptiveDistanceBlock: 2-3                  --
# │    │    └─MultiHeadDistanceAttention: 3-11       16,448
# │    │    └─LayerNorm: 3-12                        128
# │    │    └─LayerNorm: 3-13                        128
# │    │    └─Sequential: 3-14                       16,576
# │    │    └─Dropout: 3-15                          --
# │    └─AdaptiveDistanceBlock: 2-4                  --
# │    │    └─MultiHeadDistanceAttention: 3-16       16,448
# │    │    └─LayerNorm: 3-17                        128
# │    │    └─LayerNorm: 3-18                        128
# │    │    └─Sequential: 3-19                       16,576
# │    │    └─Dropout: 3-20                          --
# ├─LayerNorm: 1-4                                   128
# ├─Sequential: 1-5                                  --
# │    └─Linear: 2-5                                 8,256
# │    └─GELU: 2-6                                   --
# │    └─Dropout: 2-7                                --
# │    └─Linear: 2-8                                 2,080
# │    └─GELU: 2-9                                   --
# │    └─Dropout: 2-10                               --
# │    └─Linear: 2-11                                33
# ===========================================================================
# Total params: 144,001
# Trainable params: 144,001
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# # Main Annealing Loop

# %%
# writing all hyperparameters in one place
EPOCHS_DBAR = 2000
BATCH_SIZE_DBAR = 32
NUM_SAMPLES_IN_BATCH_DBAR = 128
LR_DBAR = 1e-4
WEIGHT_DECAY_DBAR = 1e-5
TOL_TRAIN_DBAR = 1e-6
PROBS_DBAR = torch.tensor(T_P)

EPOCHS_TRAIN_Y = 100 
BATCH_SIZE_TRAIN_Y = None
LR_TRAIN_Y = 1e-4 
WEIGHT_DECAY_TRAIN_Y = 1e-5
TOL_TRAIN_Y = 1e-4

BETA_INIT = 10.0
BETA_F = 10000.0
BETA_GROWTH_RATE = 1.1 
PERTURBATION_STD = 0.01 



Y_opt, pi, history_y_all, history_pi_all , Betas = TrainAnneal(
    model,
    X,
    Y,
    env,
    device,
    # TrainDbar hyperparameters
    epochs_dbar=EPOCHS_DBAR,
    batch_size_dbar=BATCH_SIZE_DBAR,
    num_samples_in_batch_dbar=NUM_SAMPLES_IN_BATCH_DBAR,
    lr_dbar=LR_DBAR,
    weight_decay_dbar=WEIGHT_DECAY_DBAR,
    tol_train_dbar=TOL_TRAIN_DBAR,
    # trainY hyperparameters
    epochs_train_y=EPOCHS_TRAIN_Y,
    batch_size_train_y=BATCH_SIZE_TRAIN_Y,
    lr_train_y=LR_TRAIN_Y,
    weight_decay_train_y=WEIGHT_DECAY_TRAIN_Y,
    tol_train_y=TOL_TRAIN_Y,
    # annealing schedule
    beta_init=BETA_INIT,
    beta_final=BETA_F,
    beta_growth_rate=BETA_GROWTH_RATE,
    perturbation_std=PERTURBATION_STD,
)
scenario_name += f"EpD{EPOCHS_DBAR}BSD{BATCH_SIZE_DBAR}NSD{NUM_SAMPLES_IN_BATCH_DBAR}LRD{LR_DBAR}"
scenario_name += f"EpY{EPOCHS_TRAIN_Y}LRY{LR_TRAIN_Y}"
scenario_name += f"_{BETA_INIT}to{BETA_F}rate{BETA_GROWTH_RATE}_Pert{PERTURBATION_STD}"
# Out:
# === Annealing step: Beta = 1.000e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 8.849e+01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 4.184e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 2.581e-01
# [trainY] Epoch 0, F: -2.615e-01
# [trainY] Converged at epoch 1, F: -2.615e-01
#
# === Annealing step: Beta = 1.100e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.894e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.896e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.521e-01
# [trainY] Epoch 0, F: -2.277e-01
# [trainY] Converged at epoch 1, F: -2.277e-01
#
# === Annealing step: Beta = 1.210e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.127e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.423e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.117e-01
# [trainY] Epoch 0, F: -1.975e-01
# [trainY] Converged at epoch 1, F: -1.976e-01
#
# === Annealing step: Beta = 1.331e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.223e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.076e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.011e-01
# [trainY] Epoch 0, F: -1.691e-01
# [trainY] Converged at epoch 1, F: -1.691e-01
#
# === Annealing step: Beta = 1.464e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.445e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.722e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.265e-02
# [trainY] Epoch 0, F: -1.427e-01
# [trainY] Converged at epoch 1, F: -1.427e-01
#
# === Annealing step: Beta = 1.611e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.363e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.079e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.113e-01
# [trainY] Epoch 0, F: -1.190e-01
# [trainY] Converged at epoch 1, F: -1.190e-01
#
# === Annealing step: Beta = 1.772e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.166e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.142e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.036e-01
# [trainY] Epoch 0, F: -9.674e-02
# [trainY] Converged at epoch 1, F: -9.674e-02
#
# === Annealing step: Beta = 1.949e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.468e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.048e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.041e-01
# [trainY] Epoch 0, F: -7.784e-02
# [trainY] Converged at epoch 1, F: -7.785e-02
#
# === Annealing step: Beta = 2.144e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.067e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.128e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.133e-01
# [trainY] Epoch 0, F: -5.918e-02
# [trainY] Converged at epoch 1, F: -5.919e-02
#
# === Annealing step: Beta = 2.358e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.425e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.155e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.216e-01
# [trainY] Epoch 0, F: -4.278e-02
# [trainY] Converged at epoch 1, F: -4.278e-02
#
# === Annealing step: Beta = 2.594e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.514e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.250e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.194e-01
# [trainY] Epoch 0, F: -2.835e-02
#
# === Annealing step: Beta = 2.853e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.185e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.506e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.477e-01
# [trainY] Epoch 0, F: -1.651e-02
#
# === Annealing step: Beta = 3.138e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.256e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.622e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.583e-01
# [trainY] Epoch 0, F: -7.323e-03
#
# === Annealing step: Beta = 3.452e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.147e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.526e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.478e-01
# [trainY] Epoch 0, F: -7.008e-04
#
# === Annealing step: Beta = 3.797e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.155e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.464e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.446e-01
# [trainY] Epoch 0, F: 3.028e-03
#
# === Annealing step: Beta = 4.177e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.513e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.434e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.426e-01
# [trainY] Epoch 0, F: 6.492e-03
#
# === Annealing step: Beta = 4.595e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.174e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.295e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.345e-01
# [trainY] Epoch 0, F: 8.435e-03
#
# === Annealing step: Beta = 5.054e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.696e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.233e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.206e-01
# [trainY] Epoch 0, F: 9.544e-03
#
# === Annealing step: Beta = 5.560e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.717e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.285e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.120e-01
# [trainY] Epoch 0, F: 9.932e-03
#
# === Annealing step: Beta = 6.116e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.641e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.018e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.066e-01
# [trainY] Epoch 0, F: 1.075e-02
#
# === Annealing step: Beta = 6.727e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.386e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.562e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.100e-02
# [trainY] Epoch 0, F: 1.081e-02
#
# === Annealing step: Beta = 7.400e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.190e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.916e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 8.461e-02
# [trainY] Epoch 0, F: 1.098e-02
#
# === Annealing step: Beta = 8.140e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.062e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.533e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 7.897e-02
# [trainY] Epoch 0, F: 1.179e-02
#
# === Annealing step: Beta = 8.954e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 1.936e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 8.852e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 8.214e-02
# [trainY] Epoch 0, F: 1.244e-02
#
# === Annealing step: Beta = 9.850e+01 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.033e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.326e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 8.866e-02
# [trainY] Epoch 0, F: 1.274e-02
#
# === Annealing step: Beta = 1.083e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.391e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 9.763e-02
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.251e-02
# [trainY] Epoch 0, F: 1.316e-02
#
# === Annealing step: Beta = 1.192e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 1.856e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.055e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 8.620e-02
# [trainY] Epoch 0, F: 1.286e-02
#
# === Annealing step: Beta = 1.311e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 1.973e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.067e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 9.545e-02
# [trainY] Epoch 0, F: 1.322e-02
#
# === Annealing step: Beta = 1.442e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.449e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.081e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.041e-01
# [trainY] Epoch 0, F: 1.329e-02
#
# === Annealing step: Beta = 1.586e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.280e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.039e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.067e-01
# [trainY] Epoch 0, F: 1.313e-02
#
# === Annealing step: Beta = 1.745e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.561e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.087e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.046e-01
# [trainY] Epoch 0, F: 1.211e-02
#
# === Annealing step: Beta = 1.919e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.620e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.238e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.109e-01
# [trainY] Epoch 0, F: 1.165e-02
#
# === Annealing step: Beta = 2.111e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.827e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.187e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.017e-01
# [trainY] Epoch 0, F: 1.126e-02
#
# === Annealing step: Beta = 2.323e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.355e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.209e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.205e-01
# [trainY] Epoch 0, F: 1.076e-02
#
# === Annealing step: Beta = 2.555e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.709e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.244e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.098e-01
# [trainY] Epoch 0, F: 1.017e-02
#
# === Annealing step: Beta = 2.810e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.636e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.291e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.285e-01
# [trainY] Epoch 0, F: 9.703e-03
#
# === Annealing step: Beta = 3.091e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.149e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.493e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.200e-01
# [trainY] Epoch 0, F: 9.432e-03
#
# === Annealing step: Beta = 3.400e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.012e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.240e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.311e-01
# [trainY] Epoch 0, F: 9.486e-03
#
# === Annealing step: Beta = 3.740e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.923e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.366e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.205e-01
# [trainY] Epoch 0, F: 9.554e-03
#
# === Annealing step: Beta = 4.114e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.480e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.238e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.139e-01
# [trainY] Epoch 0, F: 9.575e-03
#
# === Annealing step: Beta = 4.526e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.892e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.039e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.134e-01
# [trainY] Epoch 0, F: 9.731e-03
#
# === Annealing step: Beta = 4.979e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.746e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.483e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.293e-01
# [trainY] Epoch 0, F: 9.335e-03
#
# === Annealing step: Beta = 5.476e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.762e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.331e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.212e-01
# [trainY] Epoch 0, F: 9.332e-03
#
# === Annealing step: Beta = 6.024e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.330e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.344e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.317e-01
# [trainY] Epoch 0, F: 9.335e-03
#
# === Annealing step: Beta = 6.626e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.671e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.680e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.160e-01
# [trainY] Epoch 0, F: 9.486e-03
#
# === Annealing step: Beta = 7.289e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.730e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.626e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.391e-01
# [trainY] Epoch 0, F: 9.422e-03
#
# === Annealing step: Beta = 8.018e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.152e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.310e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.254e-01
# [trainY] Epoch 0, F: 9.652e-03
#
# === Annealing step: Beta = 8.820e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.061e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.628e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.089e-01
# [trainY] Epoch 0, F: 9.835e-03
#
# === Annealing step: Beta = 9.702e+02 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.276e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.539e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.350e-01
# [trainY] Epoch 0, F: 9.646e-03
#
# === Annealing step: Beta = 1.067e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.534e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.644e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.419e-01
# [trainY] Epoch 0, F: 9.558e-03
#
# === Annealing step: Beta = 1.174e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.866e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.446e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.106e-01
# [trainY] Epoch 0, F: 9.730e-03
#
# === Annealing step: Beta = 1.291e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.998e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.360e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.238e-01
# [trainY] Epoch 0, F: 9.827e-03
#
# === Annealing step: Beta = 1.420e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.540e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.486e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.466e-01
# [trainY] Epoch 0, F: 1.000e-02
#
# === Annealing step: Beta = 1.562e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.921e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.712e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.223e-01
# [trainY] Epoch 0, F: 9.974e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 1.719e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.044e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.568e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.312e-01
# [trainY] Epoch 0, F: 1.010e-02
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 1.891e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.460e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.704e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.466e-01
# [trainY] Epoch 0, F: 9.951e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 2.080e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.336e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.712e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.684e-01
# [trainY] Epoch 0, F: 9.894e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 2.288e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.226e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.655e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.541e-01
# [trainY] Epoch 0, F: 9.906e-03
# [trainY] Converged at epoch 99, F: 9.745e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 2.516e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.393e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.370e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.662e-01
# [trainY] Epoch 0, F: 9.984e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 2.768e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 4.146e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.578e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.611e-01
# [trainY] Epoch 0, F: 9.906e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 3.045e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.130e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.613e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.407e-01
# [trainY] Epoch 0, F: 9.728e-03
# [trainY] Converged at epoch 90, F: 9.573e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 3.349e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.514e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.777e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.277e-01
# [trainY] Epoch 0, F: 9.865e-03
# [trainY] Converged at epoch 56, F: 9.779e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 3.684e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.560e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.474e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.348e-01
# [trainY] Epoch 0, F: 9.855e-03
# [trainY] Converged at epoch 72, F: 9.741e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 4.053e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.983e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.404e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.215e-01
# [trainY] Epoch 0, F: 9.925e-03
# [trainY] Converged at epoch 82, F: 9.782e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 4.458e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.140e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.471e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.484e-01
# [trainY] Epoch 0, F: 9.773e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 4.904e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.826e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.484e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.302e-01
# [trainY] Epoch 0, F: 9.730e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 5.394e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.555e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.767e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.318e-01
# [trainY] Epoch 0, F: 9.957e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 5.933e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.441e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.393e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.377e-01
# [trainY] Epoch 0, F: 9.667e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 6.527e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.337e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.690e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.318e-01
# [trainY] Epoch 0, F: 9.664e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 7.180e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 3.739e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.572e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.454e-01
# [trainY] Epoch 0, F: 9.870e-03
# [trainY] Converged at epoch 79, F: 9.746e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 7.897e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.423e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.269e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.623e-01
# [trainY] Epoch 0, F: 9.790e-03
# [trainY] Converged at epoch 66, F: 9.684e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 8.687e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.725e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.381e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.314e-01
# [trainY] Epoch 0, F: 9.965e-03
# [trainY] Converged at epoch 92, F: 9.812e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.
#
# === Annealing step: Beta = 9.556e+03 ===
# [TrainDbar_Hybrid_vec] Epoch 0, MSE Loss: 2.837e-01
# [TrainDbar_Hybrid_vec] Epoch 1000, MSE Loss: 1.484e-01
# [TrainDbar_Hybrid_vec] Epoch 2000, MSE Loss: 1.161e-01
# [trainY] Epoch 0, F: 9.951e-03
# [Warning] Some cluster centers are out of [0,1] range. Consider decreasing lr_train_y or increasing perturbation_std.

# %%
from Plotter import PlotClustering
from Env import ClusteringEnvNumpy, ClusteringEnvTorch
try:
    X_np = X.detach().cpu().numpy()
    y_np = Y_opt.detach().cpu().numpy()
except:
    X_np = X
    y_np = Y_opt
print(scenario_name)
PlotClustering(
    X_np,
    y_np,
    pi,
    figsize=(12, 6),
    cmap="gist_rainbow",
    point_size=10,
    centroid_size=200,
    alpha=0.9,
    data_edge_color='white',
    cluster_edge_color='black',
    save_path=f"Results/{scenario_name}.png",
)
from ClusteringGroundTruth import distortion
# kappa = float(scenario_name.split("_kappa")[1].split("_")[0])
# gamma = float(scenario_name.split("_gamma")[1].split("_")[0])
# zeta = float(scenario_name.split("_zeta")[1].split("_")[0])
# T = float(scenario_name.split("_T")[1].split("_")[0])
# N = X_np.shape[0]
# d = X_np.shape[1]
# M = y_np.shape[0]
env = ClusteringEnvNumpy(
    n_data=N,
    n_clusters=M,
    n_features=d,
    parametrized=True,
    kappa=kappa,
    gamma=gamma,
    zeta=zeta,
    T=T,
    T_p=None,
)
rho = np.ones(N) / N  # Uniform weights
print("Distortion:", distortion(X_np, y_np, rho, pi, env))
# Out:
# UDT_M50eps0.4gam0.0zet1.0T0.01D64_L4_H8_FF128_DO0.01_EpD2000BSD32NSD128LRD0.0001EpY100LRY0.0001_10.0to10000.0rate1.1_Pert0.01
# Distortion: 0.009697407286917916

# %% [markdown]
# # Save the Results

# %%
# import pickle



# save_dict = {
#     "N": N,
#     "M": M,
#     "d": d,
#     # Hyperparameters
#     "EPOCHS_DBAR": EPOCHS_DBAR,
#     "BATCH_SIZE_DBAR": BATCH_SIZE_DBAR,
#     "NUM_SAMPLES_IN_BATCH_DBAR": NUM_SAMPLES_IN_BATCH_DBAR,
#     "LR_DBAR": LR_DBAR,
#     "WEIGHT_DECAY_DBAR": WEIGHT_DECAY_DBAR,
#     "TOL_TRAIN_DBAR": TOL_TRAIN_DBAR,
#     "PROBS_DBAR": PROBS_DBAR,
#     "EPOCHS_TRAIN_Y": EPOCHS_TRAIN_Y,
#     "BATCH_SIZE_TRAIN_Y": BATCH_SIZE_TRAIN_Y,
#     "LR_TRAIN_Y": LR_TRAIN_Y,
#     "WEIGHT_DECAY_TRAIN_Y": WEIGHT_DECAY_TRAIN_Y,
#     "TOL_TRAIN_Y": TOL_TRAIN_Y,
#     "BETA_INIT": BETA_INIT,
#     "BETA_F": BETA_F,
#     "BETA_GROWTH_RATE": BETA_GROWTH_RATE,
#     "PERTURBATION_STD": PERTURBATION_STD,
#     # Results
#     "X": X,
#     "Y_opt": Y_opt,
#     "history_y_all": history_y_all,
#     "history_pi_all": history_pi_all,
#     # Model architecture
#     "INPUT_DIM": INPUT_DIM,
#     "D_MODEL": D_MODEL,
#     "N_LAYERS": N_LAYERS,
#     "N_HEADS": N_HEADS,
#     "D_FF": D_FF,
#     "DROPOUT": DROPOUT
# }

# with open(f"Results/{scenario_name}.pkl", "wb") as f:
#     pickle.dump(save_dict, f)

# %% [markdown]
# # Load the Results

# %%
import pickle
# Now craete a load function to load the results
scenario_name = "Benchmark_UDT_kappa0.4_gamma0.0_zeta1.0_T0.01_20250923_000118"
def load_results(scenario_name):
    with open(f"BenchmarkUDT/{scenario_name}.pkl", "rb") as f:
        data = pickle.load(f)
    return data
results = load_results(scenario_name)
X = results["X"]
Y_opt = results["Y_opt"]
# history_y_all = results["history_y_all"]
# history_pi_all = results["history_pi_all"]
# pi = history_pi_all[-1]
pi = results["pi_opt"]

# %%
results.keys()

# %%
from animator import animate_Clusters
# history_pi_all[0] = history_pi_all[1]
animate_Clusters(
    X.detach().cpu().numpy(),
    history_y_all,
    history_pi_all,
    Betas,
    interval=250,
    save_path=f"Results/{scenario_name}.gif",
)
