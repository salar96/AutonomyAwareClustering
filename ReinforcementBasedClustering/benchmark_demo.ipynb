# %%
import numpy as np
import torch
from ADEN import ADEN
from torchinfo import summary
from TestCaseGenerator import data_RLClustering
from ADENTrain import TrainAnneal
import utils
from Env import ClusteringEnvNumpy, ClusteringEnvTorch
from ClusteringGroundTruth import cluster_gt
import pickle
from datetime import datetime

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
utils.set_seed(0)  # for reproducibility
# Out:
# Using device: cuda
# [Seed fixed to 0]

# %%
# get a list of all files inside Benchmark Folder
import os
benchmark_folder = 'Benchmark'
all_files = os.listdir(benchmark_folder)
all_files = [f for f in all_files if os.path.isfile(os.path.join(benchmark_folder, f))]

# loop over all files
for file_name in all_files:
    with open(os.path.join(benchmark_folder, file_name), 'rb') as f:
        data = pickle.load(f)

    scenario_name = data["scenario_name"]
    Y_GT = data["Y_GT"]
    pi_GT = data["pi_GT"]
    Y_opt = data["Y_opt"]
    pi_opt = data["pi_opt"]
    Y_ig = data["Y_ig"]
    pi_ig = data["pi_ig"]
    # Calculate the error of Y_opt and Y_ig with respect to Y_GT
    error_opt = np.mean((Y_GT - Y_opt) ** 2) / np.mean(Y_GT ** 2) * 100
    error_ig = np.mean((Y_GT - Y_ig) ** 2) / np.mean(Y_GT ** 2) * 100
    print(f"Scenario: {scenario_name}, Error of Optimal %: {error_opt:.1f}, Error of Ignoring %: {error_ig:.1f}")
# Out:
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta0.5_T0.001, Error of Optimal %: 0.1, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta0.5_T0.01, Error of Optimal %: 0.2, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta0.5_T1.0, Error of Optimal %: 0.3, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta0.5_T100.0, Error of Optimal %: 19.8, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta1.0_T0.001, Error of Optimal %: 0.1, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta1.0_T0.01, Error of Optimal %: 0.1, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta1.0_T1.0, Error of Optimal %: 0.4, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.0_zeta1.0_T100.0, Error of Optimal %: 0.5, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta0.5_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta0.5_T0.01, Error of Optimal %: 0.3, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta0.5_T1.0, Error of Optimal %: 0.4, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta0.5_T100.0, Error of Optimal %: 0.7, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta1.0_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta1.0_T0.01, Error of Optimal %: 0.3, Error of Ignoring %: 0.7
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta1.0_T1.0, Error of Optimal %: 0.3, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.1_gamma0.5_zeta1.0_T100.0, Error of Optimal %: 0.6, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta0.5_T0.001, Error of Optimal %: 4.3, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta0.5_T0.01, Error of Optimal %: 0.7, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta0.5_T1.0, Error of Optimal %: 14.7, Error of Ignoring %: 6.1
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta0.5_T100.0, Error of Optimal %: 12.8, Error of Ignoring %: 17.2
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta1.0_T0.001, Error of Optimal %: 0.6, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta1.0_T0.01, Error of Optimal %: 5.1, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta1.0_T1.0, Error of Optimal %: 9.9, Error of Ignoring %: 6.0
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.0_zeta1.0_T100.0, Error of Optimal %: 3.9, Error of Ignoring %: 17.2
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta0.5_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta0.5_T0.01, Error of Optimal %: 0.5, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta0.5_T1.0, Error of Optimal %: 1.3, Error of Ignoring %: 5.9
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta0.5_T100.0, Error of Optimal %: 5.2, Error of Ignoring %: 17.2
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta1.0_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta1.0_T0.01, Error of Optimal %: 0.5, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta1.0_T1.0, Error of Optimal %: 11.8, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.3_gamma0.5_zeta1.0_T100.0, Error of Optimal %: 4.0, Error of Ignoring %: 17.2
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta0.5_T0.001, Error of Optimal %: 14.0, Error of Ignoring %: 86.0
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta0.5_T0.01, Error of Optimal %: 21.2, Error of Ignoring %: 86.0
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta0.5_T1.0, Error of Optimal %: 4.6, Error of Ignoring %: 64.0
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta0.5_T100.0, Error of Optimal %: 5.0, Error of Ignoring %: 63.9
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta1.0_T0.001, Error of Optimal %: 54.8, Error of Ignoring %: 86.0
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta1.0_T0.01, Error of Optimal %: 32.3, Error of Ignoring %: 86.0
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta1.0_T1.0, Error of Optimal %: 5.1, Error of Ignoring %: 64.2
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.0_zeta1.0_T100.0, Error of Optimal %: 4.8, Error of Ignoring %: 63.9
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta0.5_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta0.5_T0.01, Error of Optimal %: 0.9, Error of Ignoring %: 14.8
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta0.5_T1.0, Error of Optimal %: 6.8, Error of Ignoring %: 64.6
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta0.5_T100.0, Error of Optimal %: 5.0, Error of Ignoring %: 63.9
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta1.0_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta1.0_T0.01, Error of Optimal %: 1.5, Error of Ignoring %: 14.8
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta1.0_T1.0, Error of Optimal %: 5.6, Error of Ignoring %: 64.8
# Scenario: Benchmark_parametrizedTrue_eps0.5_gamma0.5_zeta1.0_T100.0, Error of Optimal %: 5.7, Error of Ignoring %: 63.9
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta0.5_T0.001, Error of Optimal %: 20.9, Error of Ignoring %: 51.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta0.5_T0.01, Error of Optimal %: 21.1, Error of Ignoring %: 51.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta0.5_T1.0, Error of Optimal %: 0.2, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta0.5_T100.0, Error of Optimal %: 0.2, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta1.0_T0.001, Error of Optimal %: 20.6, Error of Ignoring %: 51.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta1.0_T0.01, Error of Optimal %: 20.8, Error of Ignoring %: 51.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta1.0_T1.0, Error of Optimal %: 0.1, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.0_zeta1.0_T100.0, Error of Optimal %: 0.2, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta0.5_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta0.5_T0.01, Error of Optimal %: 11.1, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta0.5_T1.0, Error of Optimal %: 0.3, Error of Ignoring %: 40.4
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta0.5_T100.0, Error of Optimal %: 0.2, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta1.0_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta1.0_T0.01, Error of Optimal %: 19.0, Error of Ignoring %: 5.8
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta1.0_T1.0, Error of Optimal %: 0.3, Error of Ignoring %: 40.4
# Scenario: Benchmark_parametrizedTrue_eps0.7_gamma0.5_zeta1.0_T100.0, Error of Optimal %: 0.2, Error of Ignoring %: 40.3
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta0.5_T0.001, Error of Optimal %: 24.1, Error of Ignoring %: 57.0
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta0.5_T0.01, Error of Optimal %: 25.4, Error of Ignoring %: 66.1
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta0.5_T1.0, Error of Optimal %: 3.1, Error of Ignoring %: 52.2
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta0.5_T100.0, Error of Optimal %: 2.9, Error of Ignoring %: 52.4
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta1.0_T0.001, Error of Optimal %: 23.3, Error of Ignoring %: 27.9
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta1.0_T0.01, Error of Optimal %: 25.5, Error of Ignoring %: 86.6
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta1.0_T1.0, Error of Optimal %: 3.1, Error of Ignoring %: 52.0
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.0_zeta1.0_T100.0, Error of Optimal %: 3.0, Error of Ignoring %: 52.4
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta0.5_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta0.5_T0.01, Error of Optimal %: 20.4, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta0.5_T1.0, Error of Optimal %: 3.7, Error of Ignoring %: 54.5
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta0.5_T100.0, Error of Optimal %: 3.5, Error of Ignoring %: 52.4
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta1.0_T0.001, Error of Optimal %: nan, Error of Ignoring %: nan
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta1.0_T0.01, Error of Optimal %: 18.0, Error of Ignoring %: 0.6
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta1.0_T1.0, Error of Optimal %: 3.5, Error of Ignoring %: 54.3
# Scenario: Benchmark_parametrizedTrue_eps0.9_gamma0.5_zeta1.0_T100.0, Error of Optimal %: 3.6, Error of Ignoring %: 52.4
